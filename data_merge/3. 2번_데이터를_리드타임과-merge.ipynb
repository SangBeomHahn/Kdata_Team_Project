# %%
import pandas as pd

# %%
cncMergeMct = pd.read_excel("/content/drive/MyDrive/프로그래밍 언어 공부 자료/인공지능/2022 데청캠/기업 프로젝트/데이터/병합 데이터/cnc, mct랑 리드타임 병합/cnc+mct를 합치고 lead를 합친 것/cnc 2년치랑 mct 2년치에 년월일만 바꾼 것/CNC+MCT_3년_merge_.xlsx")
cncMergeMct
# Out:
#      Unnamed: 0   호기_x 고객사_x                     품명  유실시간(분)  입고량_x  생산량_x  \
# 0             0  VM410    RI    DGV400 CYLINDER CAP     25.0    5.0      5
# 1             1  VM410    RI    DGV400 CYLINDER CAP     25.0    5.0      5
# 2             2  VM410    RI    DGV400 CYLINDER CAP     25.0    5.0      5
# 3             3  VM410    RI    DGV400 CYLINDER CAP     25.0    5.0      5
# 4             4  VM410    RI    DGV400 CYLINDER CAP     30.0    1.0      1
# ..          ...    ...   ...                    ...      ...    ...    ...
# 400         400  LCV56    BC  수명예지 TORCH UNDER BODY     30.0   40.0     40
# 401         401  VM410    BU                CATHODE     15.0  148.0    148
# 402         402  VM410    BU                CATHODE     15.0  148.0    148
# 403         403  VM410    BU                CATHODE     15.0  148.0    148
# 404         404  VM410    BU                CATHODE     15.0  148.0    148
#
# ...

# %% [markdown]
# ### 병합데이터와 리드타임 품명, 날짜로 병합
#
# 195개라는 사용할 수 없는 결과가 나온다.

# %%
df = pd.read_excel("/content/drive/MyDrive/프로그래밍 언어 공부 자료/인공지능/2022 데청캠/기업 프로젝트/데이터/병합 데이터/cnc, mct랑 리드타임 병합/cnc+mct를 합치고 lead를 합친 것/cnc 2년치랑 mct 2년치에 년월일만 바꾼 것/CNC_MCT_날짜, 품명 리드랑 이너조인.xlsx")

# %%
df
# Out:
#      Unnamed: 0           라우트번호  라우트ID                            공정  \
# 0             0  N2011090280100  R2_11      CNC > MCT > IPA세정 > 입고처리
# 1             1  N2011090330100  R2_11      CNC > MCT > IPA세정 > 입고처리
# 2             2  N2011170280100  R2_13              CNC > MCT > 입고처리
# 3             3  N2011170280100  R2_13              CNC > MCT > 입고처리
# 4             4  N2012070170100  R2_13              CNC > MCT > 입고처리
# ..          ...             ...    ...                           ...
# 190         190  N2204130080100  R2_24  CNC > MCT > 외주가공 > 사상 > 입고처리
# 191         191  N2204140630100  R2_13              CNC > MCT > 입고처리
# 192         192  N2204140630100  R2_13              CNC > MCT > 입고처리
# 193         193  N2204140630100  R2_13              CNC > MCT > 입고처리
# 194         194  N2204140630100  R2_13              CNC > MCT > 입고처리
#
#              품명        세부공정         날짜      시차  총 생산량     리드타임  ... 표준공수_x  \
# ...

# %% [markdown]
# ### 병합데이터와 리드타임 품명만으로 병합

# %%
df2 = pd.read_excel("/content/drive/MyDrive/프로그래밍 언어 공부 자료/인공지능/2022 데청캠/기업 프로젝트/데이터/병합 데이터/cnc, mct랑 리드타임 병합/cnc+mct를 합치고 lead를 합친 것/cnc 2년치랑 mct 2년치에 년월일만 바꾼 것/CNC_MCT_품명으로만 이너조인.xlsx")

# %%
df2
# Out:
#        Unnamed: 0           라우트번호  라우트ID                     공정  \
# 0               0  N1805040010100  R2_03        CNC > 세정 > 입고처리
# 1               1  N1805040010100  R2_03        CNC > 세정 > 입고처리
# 2               2  N1805040010100  R2_03        CNC > 세정 > 입고처리
# 3               3  N1805040010100  R2_03        CNC > 세정 > 입고처리
# 4               4  N1805040010100  R2_03        CNC > 세정 > 입고처리
# ...           ...             ...    ...                    ...
# 28915       28915  N2201240200100  R2_04  CNC > MCT > 세정 > 입고처리
# 28916       28916  N2201240200100  R2_04  CNC > MCT > 세정 > 입고처리
# 28917       28917  N2201240200100  R2_04  CNC > MCT > 세정 > 입고처리
# 28918       28918  N2201240200100  R2_04  CNC > MCT > 세정 > 입고처리
# 28919       28919  N2201240200100  R2_04  CNC > MCT > 세정 > 입고처리
#
#                           품명        세부공정       날짜_x      시차  총 생산량      리드타임  \
# 0                     FLANGE  CNC/선반/SAW 2018-05-14  181290    112   1618.66
# ...
